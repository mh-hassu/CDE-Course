# %% [markdown]
# # Tasks:
# - Using loops add a "age" key in all dictionary with defualt value as None
# - Using a list to convert the customer dictionary to list of list (make sure in nexted list you have only the values NOT keys))
# - Convert this (list of dict) to (dict of dict)
# - remove all customer id from dict of dict
# - using all by comprehension

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# %%
# Task 1 normal code

for customer in customers:
    customer['age'] = None      # -->  Task 1

customers
# Out:
# [{'customer id': 0,
#   'first name': 'John',
#   'last name': 'Ogden',
#   'address': '301 Arbor Rd.',
#   'age': None},
#  {'customer id': 1,
#   'first name': 'Ann',
#   'last name': 'Sattermyer',
#   'address': 'PO Box 1145',
#   'age': None},
#  {'customer id': 2,
#   'first name': 'Jill',
#   'last name': 'Somers',
#   'address': '3 Main St.',
#   'age': None}]

# %%
for customer in customers:
    print({**customer, "age":None })
# Out:
# {'customer id': 0, 'first name': 'John', 'last name': 'Ogden', 'address': '301 Arbor Rd.', 'age': None}
# {'customer id': 1, 'first name': 'Ann', 'last name': 'Sattermyer', 'address': 'PO Box 1145', 'age': None}
# {'customer id': 2, 'first name': 'Jill', 'last name': 'Somers', 'address': '3 Main St.', 'age': None}

# %%
# Task 1 Comprehension

customers = [{**customer, "age":None }for customer in customers]
customers
# Out:
# [{'customer id': 0,
#   'first name': 'John',
#   'last name': 'Ogden',
#   'address': '301 Arbor Rd.',
#   'age': None},
#  {'customer id': 1,
#   'first name': 'Ann',
#   'last name': 'Sattermyer',
#   'address': 'PO Box 1145',
#   'age': None},
#  {'customer id': 2,
#   'first name': 'Jill',
#   'last name': 'Somers',
#   'address': '3 Main St.',
#   'age': None}]

# %%
# Task 2 normal code

list_of_list = []
for customer in customers:     # --> Task 2
    list_of_list.append(list(customer.values()))

list_of_list
# Out:
# [['John', 'Ogden', '301 Arbor Rd.', None],
#  ['Ann', 'Sattermyer', 'PO Box 1145', None],
#  ['Jill', 'Somers', '3 Main St.', None]]

# %%
# Task 2 doing with Comprehension

[ list(customer.values()) for customer in customers]
# Out:
# [['John', 'Ogden', '301 Arbor Rd.', None],
#  ['Ann', 'Sattermyer', 'PO Box 1145', None],
#  ['Jill', 'Somers', '3 Main St.', None]]

# %%
# Task 3 normal code

dict_of_dict = {}
for index, item in enumerate(customers):  # ---> Task 3
    popped = item.pop('customer id')
    dict_of_dict[index] = item
    
dict_of_dict
# Out:
# {0: {'first name': 'John',
#   'last name': 'Ogden',
#   'address': '301 Arbor Rd.',
#   'age': None},
#  1: {'first name': 'Ann',
#   'last name': 'Sattermyer',
#   'address': 'PO Box 1145',
#   'age': None},
#  2: {'first name': 'Jill',
#   'last name': 'Somers',
#   'address': '3 Main St.',
#   'age': None}}

# %%
# Task 3  comprehension

{customer.pop('customer id'):customer for customer in customers}
# Out:
# {0: {'first name': 'John', 'last name': 'Ogden', 'address': '301 Arbor Rd.'},
#  1: {'first name': 'Ann', 'last name': 'Sattermyer', 'address': 'PO Box 1145'},
#  2: {'first name': 'Jill', 'last name': 'Somers', 'address': '3 Main St.'}}
