# %% [markdown]
# # Imtiaz Super Market

# %%
print("-------Welcome To Our Super Market-------")

# %%
Items = []
while True:
    things = input("Enter the thing you want to buy.if you are done with shopping write (done): ")
    
    if things.lower() == "done" :
        break 
    Items.append(things)    
print(Items)
# Out:
# Enter the thing you want to buy.if you are done with shopping write (done):  milk
# Enter the thing you want to buy.if you are done with shopping write (done):  done
# ['milk']
