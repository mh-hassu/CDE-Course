# %%
print('Hello World...')
# Out:
# Hello World...

# %% [markdown]
# # Variables

# %%
name = 'Muhammad Hassaan'
age = 17 
weight = 65 
is_present = True
print("name is a",type(name))
print("age is a",type(age))
print("weight is a",type(weight))
print(type(is_present))
name
# Out:
# name is a <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>
# 'Muhammad Hassaan'

# %% [markdown]
# # Concatenation Of Variables

# %%
first_name = 'Muhammad'
last_name = 'Hassaan'
full_name = first_name +" "+ last_name
print(full_name)
# Out:
# Muhammad Hassaan

# %%
"{0} {1}".format("Muhammad","Hassaan")
# Out:
# 'Muhammad Hassaan'

# %%
name = "Ali" 
print(id(name))
# Out:
# 1979115790688

# %% [markdown]
# ## Python Shortcuts
# Esp + B    #to make new cell after present cell
# Esp + A    #to make new cell below present cell
# Esp + DD   #to delete the current cell
# Esp + M    #to convert into markdown
# Esp + R   #to convert into Raw
# Esp + Y    #to convert into code
# #1 .....#6 (for level
# shift + Enter   #to run and make a new cell
# ctrl + enter   #to run the cell and stay in it

# %% [markdown]
# # Python Operators

# %%
print(10  + 5) #this is Addition operation 
print(15 - 13) #this is Subtraction operation 
print(45  /  2)  #this is division Operation 
print(2 * 6)   #this is multiplication Operation 
print(45 // 2) #this is for division and answer get in  round off  Operation
print(3 ** 3) #this is exponential Operation
print(40 % 3 ) #this is for remainder ,Modolus Operation
# Out:
# 15
# 2
# 22.5
# 12
# 22
# 27
# 1

# %%
5 < 6
# Out:
# True

# %% [markdown]
# # PEMDAS
# P for parenthesis ,
# E for Exponential ,
# M for Multiplication,
# D for Division,
# A for Addition ,
# S for Subtraction,

# %%
(5-4)-(4-3)-4/5
# Out:
# -0.8
