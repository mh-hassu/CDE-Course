# %% [markdown]
# # Functions

# %%
# very basic function
def add_num():     #parameter
    num1 = int(input("Enter the number1:"))
    num2 = int(input("Enter the number2: "))
    sum = num1 + num2 
    print(sum)

# %%
add_num()   #arguements
# Out:
# Enter the number1: 1
# Enter the number2:  2
# 3

# %%
def add_num(num1,num2): #parameter
    sum = num1 + num2 
    print(sum)

# %%
num1 = int(input("Enter the number1:"))
num2 = int(input("Enter the number2: "))

add_num(num1,num2)  #arguements
# Out:
# Enter the number1: 5
# Enter the number2:  2
# 7

# %%
def add_num(num1,num2=5): #parameter
    sum = num1 + num2 
    print(sum)

# %%
add_num(1)
# Out:
# 6

# %%
add_num(1,2)
# Out:
# 3

# %%
def add_num(name,num1,num2=5): #parameter
    sum = num1 + num2 
    print(f"{name} total is {sum}")

# %%
# add_num(1,9,"Hassaan") 
add_num("Hassaan",1,2)
# Out:
# Hassaan total is 3

# %%
add_num(name="Hassaan",num1=1,num2=2)
# Out:
# Hassaan total is 3

# %%
name = str(input("Enter the name: "))
num1 = int(input("Enter the number1:"))
num2 = int(input("Enter the number2: "))

#add_num(name = name,num1 = num1,num2 = num2)
add_num (num1=num1,num2=num2,name=name)
#add_num(name,num1,num2)
# Out:
# Enter the name:  hassaan
# Enter the number1: 1
# Enter the number2:  2
# hassaan total is 3

# %%
def add_num(name,*nums):# ** --> Dict  # *---> List
    print(name)
    print(*nums)

# %%
add_num("Hassaan",1,2,3,4,5,6)
# Out:
# Hassaan
# 1 2 3 4 5 6

# %% [markdown]
# 1.Task: give me the sum of the values passed as unknows args to function **args**
# 2.Task: give me the sum of the values passed as unknows args to function **kwargs**

# %%
def add_num(name=name,num_1=num1,num_2=num2):
    name = str(input("Enter the name: "))
    num_1 = int(input("Enter the number1:"))
    num_2 = int(input("Enter the number2: "))

# %%
def add_nums(name,*nums):
    result = 0
    for temp in nums:
        result += temp
    print(f"{name} : {result}")

add_nums("Hassaan",1,2,3,4,5,6,7)
# Out:
# Hassaan : 28

# %%
def add_nums(name,*nums):
    print(f"{name} : {sum(nums)}")

add_nums("Hassaan",1,2,3,4,5,6,7)
# Out:
# Hassaan : 28

# %% [markdown]
# Task 2 :

# %%
#def add_nums(name,**nums):
    result = 0
    for temp in nums.values():
        result += temp
    print(f"{name} : {result}")

add_nums("Hassaan",num_0=1,num1=2,num=3,num3=4,num4=5,num5=6,num6=7)
# Out:
# Hassaan : 28

# %%
def add_nums(name,**nums):
    print(name)
    print(nums)
    print(sum(nums.values()))

add_nums("Hassaan",num_0=1,num1=2,num=3,num3=4,num4=5,num5=6,num6=7)
# Out:
# Hassaan
# {'num_0': 1, 'num1': 2, 'num': 3, 'num3': 4, 'num4': 5, 'num5': 6, 'num6': 7}
# 28

# %%
def add_nums(name,**nums):
    print(f"{name} : {sum(nums.values())}")

add_nums("Hassaan",num_0=1,num1=2,num=3,num3=4,num4=5,num5=6,num6=7)
# Out:
# Hassaan : 28

# %%
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
        return n*factorial(n-1)
        
print(factorial(4))
# Out:
# 24

# %%
def funtions():
    pass

# %%
fact =1
num = int(input("Enter the Number that u want to calculate the factorial: "))
while (num>0):
    fact*=num
    num-=1
    
fact
# Out:
# Enter the Number that u want to calculate the factorial:  5
# 120

# %% [raw]
# while <condition>:
#     <body
#     -if needed incerement or decrement
#     -user input
#     >

# %%
user_input = "Qasim"
while (user_input != "quit"):
    print(user_input)
    user_input = input("Enter input value: ")
# Out:
# Qasim
# Enter input value:  ali
# ali
# Enter input value:  ahmed
# ahmed
# Enter input value:  Hassan
# Hassan
# Enter input value:  quit
