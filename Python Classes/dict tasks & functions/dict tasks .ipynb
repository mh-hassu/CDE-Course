# %% [markdown]
# # Tasks:
# - Using loops add a "age" key in all dictionary with defualt value as None
# - Using a list to convert the customer dictionary to list of list (make sure in nexted list you have only the values NOT keys))
# - Convert this (list of dict) to (dict of dict)

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# %%
for customer in customers:
    customer["age"]= None

# %%
customers
# Out:
# [{'customer id': 0,
#   'first name': 'John',
#   'last name': 'Ogden',
#   'address': '301 Arbor Rd.',
#   'age': None},
#  {'customer id': 1,
#   'first name': 'Ann',
#   'last name': 'Sattermyer',
#   'address': 'PO Box 1145',
#   'age': None},
#  {'customer id': 2,
#   'first name': 'Jill',
#   'last name': 'Somers',
#   'address': '3 Main St.',
#   'age': None}]

# %%
dict_of_dict ={}

for index,item in enumerate (customers):
    popped =item.pop("customer id")
    dict_of_dict[index] = item
dict_of_dict
# Out:
# {0: {'first name': 'John',
#   'last name': 'Ogden',
#   'address': '301 Arbor Rd.',
#   'age': None},
#  1: {'first name': 'Ann',
#   'last name': 'Sattermyer',
#   'address': 'PO Box 1145',
#   'age': None},
#  2: {'first name': 'Jill',
#   'last name': 'Somers',
#   'address': '3 Main St.',
#   'age': None}}

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# %% [raw]
# list_of_list = []          # mehtod 1
#
# for customer in customers:
#     list_of_list.append(list (customer.values()))
#
# list_of_list

# %%
[list(customer.values()) for customer in customers]  # MEHTOD 2
# Out:
# [[0, 'John', 'Ogden', '301 Arbor Rd.'],
#  [1, 'Ann', 'Sattermyer', 'PO Box 1145'],
#  [2, 'Jill', 'Somers', '3 Main St.']]

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]
customers = [customer.setdefault('age') for customer in customers ]
customers
# Out:
# [None, None, None]

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]
for customer in customers:
    print({**customer, "age": None})
# Out:
# {'customer id': 0, 'first name': 'John', 'last name': 'Ogden', 'address': '301 Arbor Rd.', 'age': None}
# {'customer id': 1, 'first name': 'Ann', 'last name': 'Sattermyer', 'address': 'PO Box 1145', 'age': None}
# {'customer id': 2, 'first name': 'Jill', 'last name': 'Somers', 'address': '3 Main St.', 'age': None}

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# task3 method 2
for index, item in enumerate(customers):
    print(item)
# Out:
# {'customer id': 0, 'first name': 'John', 'last name': 'Ogden', 'address': '301 Arbor Rd.'}
# {'customer id': 1, 'first name': 'Ann', 'last name': 'Sattermyer', 'address': 'PO Box 1145'}
# {'customer id': 2, 'first name': 'Jill', 'last name': 'Somers', 'address': '3 Main St.'}

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# %% [markdown]
# # Tasks:
#  -using all by comprehension
#  -Using loops add a "age" key in all dictionary with defualt value as None
#  -Using a list to convert the customer dictionary to list of list (make sure in nexted list you have only the values NOT keys))
#  -Convert this (list of dict) to (dict of dict)

# %%
customers = [
    {     
    "customer id": 0,
    "first name":"John",
    "last name": "Ogden",
    "address": "301 Arbor Rd.",
     },
     {
     "customer id": 1,
     "first name":"Ann",
         
     "last name": "Sattermyer",
     "address": "PO Box 1145",
     },
     {
     "customer id": 2,
    "first name":"Jill",
    "last name": "Somers",
    "address": "3 Main St.",
    },
]

# %%
# Using loops add a "age" key in all dictionary with defualt value as None
list_of_dict_age = []
for customer in customers:                                # mehtod 1
    list_of_dict_age = (customer.setdefault('age')) 
    print(customer)
