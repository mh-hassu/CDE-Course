# %%
dict_customers = {
   'customer_id': 1,
    'customer_name':'Hassaan',
    'discounts': ["standard","volume","loyalty"]
    }

# %%
dict_customers ["discounts"][1]
# Out:
# 'volume'

# %%
lst = ["Ali","Hassaan","Ahmed"]  # list are order
lst
# Out:
# ['Ali', 'Hassaan', 'Ahmed']

# %%
set1 = set(lst)  # set are unorder
set1
# Out:
# {'Ahmed', 'Ali', 'Hassaan'}

# %% [markdown]
# # Functions

# %%
num1 = 5
num2 = 7
print(num1 + num2)
# Out:
# 12

# %%
def addition ():
    num1 = int(input("Enter the First number: "))
    num2 = int(input("Enter the Second number: "))
    print(num1 + num2)

# %%
addition ()
# Out:
# Enter the First number:  2
# Enter the Second number:  5
# 7

# %% [markdown]
# # Task :
#
#    -take two numbers and operators as an input
#    - perform calculation based on user input

# %%
def Calculator ():
    num1 = int(input("Enter the First number: "))
    num2 = int(input("Enter the Second number: "))
    operator = input("Select the Operator +,-,*,/")
    if operator == "+":  # single = assign operator   and double == relation Operator
        print(f"The Sum of {num1} and {num2} is {num1 + num2}")
    elif operator == "-":
        print(f"The Difference of {num1} and {num2} is", num1 - num2)
    elif operator == "*":
        print(f"The Product of {num1} and {num2} is", num1 * num2)
    elif operator == "/":
        print(f"The Quotient of {num1} and {num2} is", num1 / num2)
    else:
        print("Invalid Selection: ")

# %%
Calculator()
# Out:
# Enter the First number:  2
# Enter the Second number:  5
# Select the Operator +,-,*,/ *
# The Product of 2 and 5 is 10

# %%
def Calculator (num1,num2,operator):  # parameters
    num1 = int(input("Enter the First number: "))
    num2 = int(input("Enter the Second number: "))
    operator = input("Select the Operator +,-,*,/")
    if operator == "+":  # single = assign operator   and double == relation Operator
        print(f"The Sum of {num1} and {num2} is {num1 + num2}")
    elif operator == "-":
        print(f"The Difference of {num1} and {num2} is", num1 - num2)
    elif operator == "*":
        print(f"The Product of {num1} and {num2} is", num1 * num2)
    elif operator == "/":
        print(f"The Quotient of {num1} and {num2} is", num1 / num2)
    else:
        print("Invalid Selection: ")

# %%
Calculator(2,8,"*") # Arguements
# Out:
# Enter the First number:  2
# Enter the Second number:  8
# Select the Operator +,-,*,/ *
# The Product of 2 and 8 is 16

# %% [markdown]
# # Task2:
#    -1. Register a user with his name,email, and password
#        - save name,email,password in list
#     -2. Create another function to login a user with his email and password you saved as the registration time,
#    if the crediential match the data you saved, print his name and a login message if not  print message that you are not a
#    registered user please register and run the register function

# %%
global_user = {
      
    
}

# %%
global_user = []
def Register(name, email, password):
    global_user.append(name)
    global_user.append(email)
    global_user.append(password)
    print(global_user)
Register("hassaan","hassu@gmail.com","12345")
# Out:
# ['hassaan', 'hassu@gmail.com', '12345']

# %%
def login(email,password):
    if (global_user[1] == email and global_user[2] == password):
        print(f"Welcome {global_user[0]}")
    else:
        print("You are Not Registered! Please Register first")

# %%
login("hassu@gmail.com","12345")
login("ahmed@gmail.com","12345")
# Out:
# Welcome hassaan
# You are Not Registered! Please Register first

# %%
def display_result(winner, score,**other_info):
    print("The Winner was "+ winner)
    print("The Score was "+ score)
    for key,value in other_info.items():
        print(key + ":" + value)

# %%
display_result(winner="Spain",score="2-0",injuries="No",Halftime = "Two")
# Out:
# The Winner was Spain
# The Score was 2-0
# injuries:No
# Halftime:Two

# %% [markdown]
# # Task3:
# - make a dict of dict

# %%
main_dict ={
    "hassu123@gmail.com":{"name":"Hassaan","password":"hassu123"},
    "ahmed123@gmail.com":{"name":"ahmed","password":"fastfast"}
}
def login(email,name,password):
    if main_dict [email]:
        #print(main_dict[email])
        if main_dict[email]["name"]["password"] and main_dict[email]["password"]:
            print(f"Wellcome{name}")
    else:
        print("Invalid")
       
login("hassu123@gmail.com","Hassaan","hassu123")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 13
#      10     else:
#      11         print("Invalid")
# ---> 13 login("hassu123@gmail.com","Hassaan","hassu123")
#
# Cell In[20], line 8, in login(email, name, password)
#       5 def login(email,name,password):
#       6     if main_dict [email]:
#       7         #print(main_dict[email])
# ----> 8         if main_dict[email]["name"]["password"] and main_dict[email]["password"]:
#       9             print(f"Wellcome{name}")
#      10     else:
#
# TypeError: string indices must be integers, not 'str'

# %%
login("hassu123@gmail.com","Hassaan","hassu123")
# Out:
# {'name': 'Hassaan', 'password': 'hassu123'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 login("hassu123@gmail.com","Hassaan","hassu123")
#
# Cell In[17], line 8, in login(email, name, password)
#       6 if main_dict [email]:
#       7     print(main_dict[email])
# ----> 8     if main_dict[email]["name"]["password"]:
#       9         print(main_dict[email]["name"]["password"])
#      10 else:
#
# TypeError: string indices must be integers, not 'str'
