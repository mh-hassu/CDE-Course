# %% [markdown]
# ## Dictionaries

# %%
lst = {
    "f_name": "Muhammad",
    "l_name"  :"Hassaan",
   "age": 17,
 "weight" : 65,
   "is_present" : True
     
}

# %%
lst.update(age =2)

# %%
lst
# Out:
# {'f_name': 'Muhammad',
#  'l_name': 'Hassaan',
#  'age': 2,
#  'weight': 65,
#  'is_present': True}

# %%
lst.update(age =17)

# %%
lst
# Out:
# {'f_name': 'Muhammad',
#  'l_name': 'Hassaan',
#  'age': 17,
#  'weight': 65,
#  'is_present': True}

# %%
lst.values()
# Out:
# dict_values(['Muhammad', 'Hassaan', 17, 65, True])

# %%
lst.keys()
# Out:
# dict_keys(['f_name', 'l_name', 'age', 'weight', 'is_present'])

# %%
lst.items()
# Out:
# dict_items([('f_name', 'Muhammad'), ('l_name', 'Hassaan'), ('age', 17), ('weight', 65), ('is_present', True)])

# %%
lst.fromkeys("age")
# Out:
# {'a': None, 'g': None, 'e': None}

# %%
lst.get("f_name")
# Out:
# 'Muhammad'

# %%
lst.pop("age")
# Out:
# 17

# %%
lst.popitem()
# Out:
# ('is_present', True)

# %%
lst
# Out:
# {'f_name': 'Muhammad', 'l_name': 'Hassaan', 'weight': 65}

# %%
lst.setdefault("number",a)  #"number" = 0322257472
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 lst.setdefault("number",a)
#
# NameError: name 'a' is not defined

# %%
lst
# Out:
# {'f_name': 'Muhammad', 'l_name': 'Hassaan', 'weight': 65, 'number': None}
